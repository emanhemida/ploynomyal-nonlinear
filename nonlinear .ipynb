# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
data=pd.read_csv("polynomial-regression.csv")
x=data.iloc[:,:-1]
y=data.iloc[:,-1:]
plt.scatter(x,y)
plt.show()

# %%
#m = LinearRegression()
#m.fit(x,y)
# print(m.score(x,y))
#bested line
# plt.scatter(x,y)
# plt.plot(x,m.predict(x))
# plt.show()
# Out:
# 0.4745823761330058

# %%
poly=PolynomialFeatures(degree=2)#هيضرب الx2
# هخزن فى الxالجديده
p_x=poly.fit_transform(x)
m=LinearRegression()
m.fit(p_x,y)
print(m.score(p_x,y))
#bested line
plt.scatter(x,y)
plt.plot(x,m.predict(p_x))
plt.show()
# Out:
# 0.81088099873991

# %%
poly=PolynomialFeatures(degree=3)#هيضرب الx3
# هخزن فى الxالجديده
p_x=poly.fit_transform(x)
m=LinearRegression()
m.fit(p_x,y)
print(m.score(p_x,y))
#bested line
plt.scatter(x,y)
plt.plot(x,m.predict(p_x))
plt.show()
# Out:
# 0.9442498220803439

# %%
poly=PolynomialFeatures(degree=4)#هيضرب الx4
# هخزن فى الxالجديده
p_x=poly.fit_transform(x)
m=LinearRegression()
m.fit(p_x,y)
print(m.score(p_x,y))
#bested line
plt.scatter(x,y)
plt.plot(x,m.predict(p_x))
plt.show()
# Out:
# 0.9694743023211779
